# %% [raw]
# ---
# title: "Predictive Inferences of gpt-4o: Everyday Essentials"
# description: "How well can gpt-4o predict my day with little to no information?"
# author: "Julia Levine"
# date: "2/17/2025"
# categories:
#   - Predictions
# ---

# %% [markdown]
# ## How well can gpt-4o predict the rest of my day?
# It's a standard Monday afternoon and I have two classes and a lot of studying to do. I'm sitting here sipping on my iced matcha and I'm wondering what comes next. I may not have all the answers, but can gpt-4o divinate some for me?

# %% [markdown]
# # The Past
# My day is almost over, so let's see how productive gpt-4o thinks I've been so far. I will start off with standard and non-descript questioning. Over time, my questioning will illuminate certain features that gpt-4o explains, thereby hopefully giving insight into an accurate future.
# ![Screenshot 2025-02-17 at 3.41.21 PM.png](attachment:fb4edb50-f113-408a-bdf1-fc1489025862.png)
#
# gpt-4o starts with some standard events that most people experience: breakfast, commuting to school/work, lunch, exercise, and running errands. However, gpt-4o is yet to understand that my schedule differs from mosts in a very important way: I'm a bit lazy. Let's let gpt-4o in on the secret and ask some questions about what I'm doing right now.

# %% [markdown]
# # The Present
# After informing gpt-4o of my laziness, I confirmed which portions of its original suggestions were accurate to my morning.
# ![Screenshot 2025-02-17 at 3.45.54 PM.png](attachment:6f523591-04a1-43ab-a545-a54ebeb08506.png)
#
# In response, gpt-4o generates a very similar present for me, including tasks like work, relaxing, and exercising. It seems that my personalized additions did not do much to change gpt-4o's presets for what a standard afternoon entails. Rather than thinking outside of the box and potentially getting some things wrong, it seems that the model prefers to stick to the standards under the guise that most individuals could relate to the listed activities in some way, shape, or form.

# %% [markdown]
# # The Future
# After explaining my present to gpt-4o, I asked it to predict my future. After a day of classes and some school work balanced with relaxing, gpt-4o predicts that my evening will end in socializing, dinner, exercise, and more work.
# ![Screenshot 2025-02-17 at 4.40.59 PM.png](attachment:ba450f47-692a-474e-84b6-079b136145bd.png)
#
# Maybe it's just me, but does my evening have to be so boring? Where's the creativity and the fun! I want gpt-4o to predict an eventful evening for me rather than a seemingly endless loop of the same 3 activities for the morning, afternoon, and evening.
#
# I am curious to know if this is just the standard response for gpt-4o, or if other people's days are more predictable than mine...
